# %% [markdown]
# ## Homework Assignment 3
# ### Due Friday, Feb 14, 2025 at 11:59 pm PT

# %% [markdown]
# *Reminder: all homework is to be completed individually.  You can work together to find a solution, but you must write the solution, including any code, individually.  You cannot write one piece of code as a group and submit it as your individual work*

# %% [markdown]
# You can submit your homework on gradescope (entry code **XGDYDR**) as a pdf of your jupyter notebook or as screen shots.  You can save the notebook in multiple forms using 'File->Download as'.  If you are using screen shots, use the screen shot command (not a picture using your phone).  E.g. on a Mac, if you type command+shift+4, you can select a part of your screen and it will return an image of that region on your desktop.

# %% [markdown]
# **Note: questions indicated by [challenge]** are intended to be difficult and will take some thought / effort on your part. They are still required, but full grades may still be awared even if you do not come up with a complete solution (i.e. please try, it is okay if you don't succeed).

# %% [markdown]
# ### Problem 1: basic matplotlib
#
# In this problem, you are free to pick your own functions.  Your goal here is to visualize a function that looks interesting.  The definition of interesting is up to you to decide.  The only thing that we are looking for is plots that show some range: we can see the changes to the function easily, and they are more than just simple straight lines
#
# **(a)** Pick a function of 1 variable, $f(x)$, defined on the range $x\in[1,10]$.  Make a 3 column plot that show $f(x)$ as a line, a scatter plot and as a bar plot (i.e. use ax[0].plot(), ax[1].scatter() and ax[2].bar()). Label the axes for each panel.
#
# **(b)** Pick a function of two variable $f(x,y)$ defined for $x\in[-10,10]$ and $y\in [-1,1]$. Make two seperate figures: one where $f(x,y)$ is represented as a contour plot and the other where it is represented a heatmap using ax.pcolor().
#
# **(c)** Make a three dimensional plot of some kind (e.g. a line or a surface).

# %% [markdown]
# ### Problem 2: Reading Documention
#
# In this problem, we are getting practice reading the documention so that we can learn how to use the many many functions that exist in python that we don't discuss in class. **Use markdown to explain how it works, like in the class notes.**
#
# Find the documention for making a pie chart [matplotlib.axes.Axes.pie](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.pie.html)
#
# **(a)** Make a basic pie chart with at least 4 components. Explain the basic inputs and how affect the figure.
#
# **(b)** Show some of the options that can be changed from their defaults. Change the colors of each slide of the pie chart to one you specified and add labels. Pick 2 more options and show how they work.
#
# **(c) $[$ Challenge $]$** If you scroll down in the documention, there are examples, including nested pie charts. Make your own nested pie chart.
#
# **(d) $[$ Challenge $]$** Make a bar plot in [polar coordinates](https://matplotlib.org/stable/gallery/pie_and_polar_charts/polar_bar.html). Show how you might make one that looks similar to a pie chart and one that looks completey different (again, feel free to use the example code as a guide, but explain how it works).

# %% [markdown]
# ## Problem 3: Extrema
#
# **(a)** Use Newton's method to write a function that finds the extrema (local maxima or minima) of a function. Show that it works correctly on a few examples.
#
# **(b)** Create a function that finds only a local minimum of a given function. You can call your function from (a) but you will need a method to tell if it is a local minimum or maximum and then keep trying if you find a local maximum. Again, demonstrate that it works on a few examples.
#
# **(c) $[$ Challenge $]$** Make a figure that illustrates the process of finding the minimum on a specific example. E.g. you might want to show the function and then show how each subsequent guess is made and how it approaches the solution (you might want to color each guess differently, for example).
