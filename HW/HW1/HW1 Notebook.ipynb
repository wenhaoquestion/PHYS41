# %% [markdown]
# # Homework Assignment 1
# ### Due Friday, Jan 17, 2025 at 11:59 pm PT

# %% [markdown]
# *Reminder: all homework is to be completed individually.  You can work together to find a solution, but you must write the solution, including any code, individually.  You cannot write one piece of code as a group and submit it as your individual work*

# %% [markdown]
# You can submit your homework on gradescope (entry code **XGDYDR**) as a pdf of your jupyter notebook or as screen shots.  You can save the notebook in multiple forms using 'File->Download as'.  If you are using screen shots, use the screen shot command (not a picture using your phone).  E.g. on a Mac, if you type command+shift+4, you can select a part of your screen and it will return an image of that region on your desktop.

# %% [markdown]
# ### Problem 1: Basic python

# %% [markdown]
# The purpose of this HW assigment is just to get used to using a jupyter notebook and doing some simple operations. This is essentially practice in how to use the notebook for your later HW.
#
# **(a)** Make a notebook with a title (e.g. HW1), your name and date in the Markdown language.  Remember that you can use #, ##, etc to change the emphasis.
#
# **(b)** Create variables a,b,c,d and assign them values a=5,b=7,c=3.14,d=99.2. Evaluate the following:
#
# (i) $a^c$
#
# (ii) $(a+b)c+d$
#
# (iii) $a/b+c/d$
#
# **(c)** Make two lists with at least 3 elements in each. Show what happens when you evaluate list1+list2.
#
# **(d)** Create a dictionary containing the information a=5,b=7,c=3.14,d=99.2 where 'a','b','c','d' (as strings) are the keys in the dictionary. Show how to print the value of the 'c' in the dictionary

# %% [markdown]
# ### Problem 2: Basic Functions

# %%
import hw1 #I am loading some solutions to show you what I want your functions to do of 2a,b

# %% [markdown]
# **(a)** Write a function that takes a list, and a single number (int/float) or string (str) as input and counts how many times the number/work appears in the list. E.g. it should do the following

# %%
list_a=['cat','dog',1,2,'bear',2,4,1]
print(hw1.solution_a(list_a,'cat'))
print(hw1.solution_a(list_a,2))
print(hw1.solution_a(list_a,3))
# Out:
# 1
# 2
# 0

# %% [markdown]
# **(b)** Write a function that takes a list of numbers and returns the sum and product of all the numbers. E.g. it should do the following:

# %%
list_b=[1.1,2.1,3.1,4.4,1.4,1.9,100,12.]

hw1.solution_b(list_b)
# Out:
# (126.0, 100574.81280000001)

# %% [markdown]
# **(c)** Your function in **(b)** probably doens't work if any elements in the list are not float or int. Make an improved version where you only add up the numbers in the list.  If anything is not a number, have your function print an error message (but still add up the entries that are numbers and return the answer). It might be useful to use the "type" operation:

# %%
print(type('a'))
print(type(2)==int)
# Out:
# <class 'str'>
# True

# %% [markdown]
# **(d)** First, create a dictionary where the keys are names of people and the data for each key is also a dictionary containing their grades in classes (this is all made up data). For example:

# %%
my_class={'Alice': {'Phys4':'A','Phys41':'A+'}}
my_class['Alice']
# Out:
# {'Phys4': 'A', 'Phys41': 'A+'}

# %% [markdown]
# Now write a function that searches through this dictionary for a students name and a class they are in and returns the grade.
