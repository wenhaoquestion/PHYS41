# %% [markdown]
# ## Homework Assignment 3

# %% [markdown]
# *Reminder: all homework is to be completed individually.  You can work together to find a solution, but you must write the solution, including any code, individually.  You cannot write one piece of code as a group and submit it as your individual work*

# %% [markdown]
# **Note: questions indicated by [challenge]** are intended to be difficult and will take some thought / effort on your part. They are still required, but full grades may still be awared even if you do not come up with a complete solution (i.e. please try, it is okay if you don't succeed).

# %% [markdown]
# ### Problem 1: Logic with numpy
#
# **(a)** Write a function that can take both numbers and numpy arrays as input, let's call it $X$. If $X$ is just a number, return $X^2$. If it is an array, use a for loop to find the largest element of the array, $y$, and have it return $y^2$. The function numpy.iterable useful. Look up the documentation on this function and show how it works and then use it in your solution.
#
# **(b)** Write a function that takes arrays $A$, $B$, and $C$ as input that are all of the same shape. You want to return an array of the same shape and takes the value of $A+B$ when $A+B > C$ AND $A+B < 2 C^2$ and return $-C$ otherwise. Use functions like np.where and np.logical_and rather than for loops. Show that your function works as desired on several examples.

# %% [markdown]
# ### Problem 2: Random Numbers
#
# **(a)** Write a function that returns the outcome of flipping a coin where it outputs "Heads" with probability $p$ and "Tails" with probability $1-p$.
#
# **(b)** Using your result from (a), now write a function that outputs an array length $N$-array of heads or tails drawn from your function in (a) but where the heads is represented by a $+1$ and tails is represented by $-1$.
#
# **(c)** [challenge]: Suppose you have 50 dollars and you play a game where you win 1 dollar when you flip heads and lose 1 dollar when you flip tails. You decide that you are going to quit the game if you win 100 dollars (so you have 150 total), but you also end the game if you run out of money (you have 0 dollars).
#
# Write a function that take a specific value of $p$ as input (as defined in Problem 2a) and simulates playing this game until either you quit with 150 dollars or lose with 0 dollars and returns the number of coin flips that occured before the game ended.
#
# Show the outcome of playing the game 10 times for $p=0.45$ and $p=0.5$.
