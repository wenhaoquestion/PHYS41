# %% [markdown]
# ## Homework Assignment 2
# ### Due Friday, Jan 24, 2025 at 11:59 pm PT

# %% [markdown]
# *Reminder: all homework is to be completed individually.  You can work together to find a solution, but you must write the solution, including any code, individually.  You cannot write one piece of code as a group and submit it as your individual work*

# %% [markdown]
# You can submit your homework on gradescope (entry code **XGDYDR**) as a pdf of your jupyter notebook or as screen shots.  You can save the notebook in multiple forms using 'File->Download as'.  If you are using screen shots, use the screen shot command (not a picture using your phone).  E.g. on a Mac, if you type command+shift+4, you can select a part of your screen and it will return an image of that region on your desktop.

# %% [markdown]
# **Note: questions indicated by [challenge]** are intended to be difficult and will take some thought / effort on your part. They are still required, but full grades may still be awared even if you do not come up with a complete solution (i.e. please try, it is okay if you don't succeed).

# %% [markdown]
# ### Problem 1: More Challenging Functions
#
# **(a)** The function below is supposed to sum the numbers from 1 to N recursively.

# %%
def mysum(N):
    if N<0:
        return 1
    else:
        return mysum(N)+N

# %% [markdown]
# but clearly it doesn't work

# %%
mysum(10)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mysum(10)
#
# Cell In[1], line 5, in mysum(N)
#       3     return 1
#       4 else:
# ----> 5     return mysum(N)+N
#
# Cell In[1], line 5, in mysum(N)
#       3     return 1
#       4 else:
# ----> 5     return mysum(N)+N
#
#     [... skipping similar frames: mysum at line 5 (2974 times)]
#
# Cell In[1], line 5, in mysum(N)
#       3     return 1
#       4 else:
# ----> 5     return mysum(N)+N
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# Find all the mistakes (there is more than one) and fix them to that the function works properly. Demonstrate that it is giving the right answers.

# %% [markdown]
# **(b)** Write a function that takes a list of strings and numbers and returns them in a list in the order: numbers in numerical order, followed by strings in alphabetical order

# %% [markdown]
# **(c)** Write a function that takes a list of numbers and basic math operations +,-,*,/ and calculates the results assuming the order of operations is just acting in order from left to right.  E.g. given the list

# %%
list1c=[2,'+',4,'-',5,'*',10]

# %% [markdown]
# we should get the result of doing the calcualtion

# %%
(2+4-5)*10
# Out:
# 10

# %% [markdown]
# Use several examples to show your function works.

# %% [markdown]
# **(d)[challenge]** Create a function that takes a list of numbers and basic math operations +,-,*,/ calculates the results according to the correct order of operations. E.g. given the list

# %%
list1d=[2,'+',4,'-',5,'*',10]

# %% [markdown]
# we should get the result of doing the calcualtion

# %%
2+4-5*10
# Out:
# -44

# %% [markdown]
# Use several examples to show your function works.

# %% [markdown]
# ### Problem 2: Basic numpy

# %%
import hw2 
import numpy as np

# %% [markdown]
# **(a)** Write a function that calculates $\sin((\omega t)^n+\phi)$ for a given $n>0$, $\omega$, and $\phi$ at times $t$ specified by a numpy array (and returns the answer in the form a numpy array of the same shape). E.g.

# %%
time=np.linspace(0,10,10)
hw2.sinn(time,1,10,1) #sinn(time,n=1,omega=10,phi=1)
# Out:
# array([ 0.84147098, -0.4396954 , -0.94284711,  0.22231267,  0.9941035 ,
#         0.00688774, -0.99251546, -0.235722  ,  0.93816742,  0.45202579])

# %% [markdown]
# **(b)** Write a function that takes as input the coefficients $a,b,c$ of a quadratic equation $a x^2 +b x+c =0$ and returns the solutions.  This function must do two things: (1) it can take numpy arrays for $a,b,c$ and return a numpy array (or arrays) of solutions and (2) it should return the complex solutions when there are no real solutions.

# %% [markdown]
# **(c)** You want to calculate the function $f(x,y,z)=\sin(x)*\cos(y)^2+z$ on a three-dimensional region $x\in[-\pi,\pi]$, $y\in[0,2\pi]$ and $z\in[-3,3]$.  To do so, you make a grid of points inside the region taking 10 values along each axis $x$,$y$ and $z$ (i.e. a minimum of 1000 points total).  Find $f(x,y,z)$ at every point in this grid using a shape (10,10,10) array and a meshgrid for the x,y,z values. Show how to return a specific entry in the array that corresponds to a specific $x$,$y$,$z$ of your grid.
